# %%
# !pip install fastapi sqlalchemy databases uvicorn nest_asyncio
# Out:
# Collecting fastapi
#   Downloading fastapi-0.115.4-py3-none-any.whl (94 kB)
#                                               0.0/94.7 kB ? eta -:--:--
#                                               0.0/94.7 kB ? eta -:--:--
#                                               0.0/94.7 kB ? eta -:--:--
#      ----                                     10.2/94.7 kB ? eta -:--:--
#      ----------------                       41.0/94.7 kB 653.6 kB/s eta 0:00:01
#      ------------------------               61.4/94.7 kB 544.7 kB/s eta 0:00:01
#      ------------------------------------   92.2/94.7 kB 581.0 kB/s eta 0:00:01
#      -------------------------------------- 94.7/94.7 kB 451.8 kB/s eta 0:00:00
# Requirement already satisfied: sqlalchemy in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (1.4.39)
# Collecting databases
#   Downloading databases-0.9.0-py3-none-any.whl (25 kB)
# Collecting uvicorn
#   Downloading uvicorn-0.32.0-py3-none-any.whl (63 kB)
#                                               0.0/63.7 kB ? eta -:--:--
#      -------------------------                41.0/63.7 kB ? eta -:--:--
#      -------------------------                41.0/63.7 kB ? eta -:--:--
#      -------------------------                41.0/63.7 kB ? eta -:--:--
#      -------------------------                41.0/63.7 kB ? eta -:--:--
#      -------------------------------------- 63.7/63.7 kB 262.2 kB/s eta 0:00:00
# Requirement already satisfied: nest_asyncio in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (1.5.6)
# Collecting starlette<0.42.0,>=0.40.0 (from fastapi)
#   Downloading starlette-0.41.2-py3-none-any.whl (73 kB)
#                                               0.0/73.3 kB ? eta -:--:--
#                                               0.0/73.3 kB ? eta -:--:--
#      ---------------                        30.7/73.3 kB 660.6 kB/s eta 0:00:01
#      ---------------------                  41.0/73.3 kB 991.0 kB/s eta 0:00:01
#      -------------------------------------- 73.3/73.3 kB 578.2 kB/s eta 0:00:00
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from fastapi) (2.6.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from fastapi) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from sqlalchemy) (2.0.1)
# Collecting sqlalchemy
#   Downloading SQLAlchemy-2.0.36-cp311-cp311-win_amd64.whl (2.1 MB)
#                                               0.0/2.1 MB ? eta -:--:--
#                                               0.0/2.1 MB ? eta -:--:--
#      -                                        0.1/2.1 MB 1.1 MB/s eta 0:00:02
#      --                                       0.1/2.1 MB 939.4 kB/s eta 0:00:03
#      --                                       0.2/2.1 MB 919.0 kB/s eta 0:00:03
#      ---                                      0.2/2.1 MB 845.5 kB/s eta 0:00:03
#      ----                                     0.2/2.1 MB 860.2 kB/s eta 0:00:03
#      ----                                     0.2/2.1 MB 758.5 kB/s eta 0:00:03
#      ----                                     0.2/2.1 MB 758.5 kB/s eta 0:00:03
#      ----                                     0.2/2.1 MB 758.5 kB/s eta 0:00:03
#      -----                                    0.3/2.1 MB 612.6 kB/s eta 0:00:03
#      ------                                   0.3/2.1 MB 655.4 kB/s eta 0:00:03
#      ------                                   0.3/2.1 MB 655.4 kB/s eta 0:00:03
#      ------                                   0.4/2.1 MB 571.7 kB/s eta 0:00:04
#      --------                                 0.4/2.1 MB 688.1 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 685.7 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 685.7 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 642.5 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 642.4 kB/s eta 0:00:03
#      ---------                                0.5/2.1 MB 642.4 kB/s eta 0:00:03
#      -----------                              0.6/2.1 MB 633.9 kB/s eta 0:00:03
#      ------------                             0.6/2.1 MB 645.3 kB/s eta 0:00:03
#      ------------                             0.6/2.1 MB 625.5 kB/s eta 0:00:03
#      -------------                            0.7/2.1 MB 646.0 kB/s eta 0:00:03
#      -------------                            0.7/2.1 MB 637.2 kB/s eta 0:00:03
#      --------------                           0.8/2.1 MB 673.7 kB/s eta 0:00:02
#      ---------------                          0.8/2.1 MB 672.6 kB/s eta 0:00:02
#      ---------------                          0.8/2.1 MB 672.6 kB/s eta 0:00:02
#      ---------------                          0.8/2.1 MB 672.6 kB/s eta 0:00:02
#      -----------------                        0.9/2.1 MB 671.0 kB/s eta 0:00:02
#      -----------------                        0.9/2.1 MB 671.0 kB/s eta 0:00:02
#      -------------------                      1.0/2.1 MB 684.1 kB/s eta 0:00:02
#      -------------------                      1.0/2.1 MB 683.1 kB/s eta 0:00:02
#      ---------------------                    1.1/2.1 MB 708.3 kB/s eta 0:00:02
#      ----------------------                   1.2/2.1 MB 719.9 kB/s eta 0:00:02
#      -----------------------                  1.2/2.1 MB 730.5 kB/s eta 0:00:02
#      -----------------------                  1.2/2.1 MB 730.5 kB/s eta 0:00:02
#      ------------------------                 1.3/2.1 MB 713.9 kB/s eta 0:00:02
#      ------------------------                 1.3/2.1 MB 713.9 kB/s eta 0:00:02
#      ------------------------                 1.3/2.1 MB 713.9 kB/s eta 0:00:02
#      ------------------------                 1.3/2.1 MB 682.7 kB/s eta 0:00:02
#      -------------------------                1.3/2.1 MB 698.4 kB/s eta 0:00:02
#      -------------------------                1.4/2.1 MB 692.5 kB/s eta 0:00:02
#      --------------------------               1.4/2.1 MB 691.1 kB/s eta 0:00:01
#      ----------------------------             1.5/2.1 MB 715.1 kB/s eta 0:00:01
#      -----------------------------            1.5/2.1 MB 713.7 kB/s eta 0:00:01
#      -----------------------------            1.5/2.1 MB 713.0 kB/s eta 0:00:01
#      -----------------------------            1.5/2.1 MB 713.0 kB/s eta 0:00:01
#      -----------------------------            1.5/2.1 MB 682.7 kB/s eta 0:00:01
#      ------------------------------           1.6/2.1 MB 695.4 kB/s eta 0:00:01
#      -------------------------------          1.6/2.1 MB 694.5 kB/s eta 0:00:01
#      -------------------------------          1.7/2.1 MB 694.1 kB/s eta 0:00:01
#      --------------------------------         1.7/2.1 MB 693.0 kB/s eta 0:00:01
#      -----------------------------------      1.8/2.1 MB 724.7 kB/s eta 0:00:01
#      -----------------------------------      1.8/2.1 MB 728.8 kB/s eta 0:00:01
#      -------------------------------------    1.9/2.1 MB 750.7 kB/s eta 0:00:01
#      -------------------------------------    2.0/2.1 MB 753.6 kB/s eta 0:00:01
#      --------------------------------------   2.0/2.1 MB 755.0 kB/s eta 0:00:01
#      ---------------------------------------- 2.1/2.1 MB 760.7 kB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from uvicorn) (8.0.4)
# Collecting h11>=0.8 (from uvicorn)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#                                               0.0/58.3 kB ? eta -:--:--
#      ---------------------                    30.7/58.3 kB ? eta -:--:--
#      ---------------------------------------- 58.3/58.3 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.1 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.16.1)
# Requirement already satisfied: anyio<5,>=3.4.0 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from starlette<0.42.0,>=0.40.0->fastapi) (3.5.0)
# Requirement already satisfied: idna>=2.8 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\new folder\new folder\lib\site-packages (from anyio<5,>=3.4.0->starlette<0.42.0,>=0.40.0->fastapi) (1.2.0)
# Installing collected packages: sqlalchemy, h11, uvicorn, starlette, databases, fastapi
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# Successfully installed databases-0.9.0 fastapi-0.115.4 h11-0.14.0 sqlalchemy-2.0.36 starlette-0.41.2 uvicorn-0.32.0

# %%
# database.py setup in Jupyter

from sqlalchemy import create_engine, MetaData
from sqlalchemy.orm import sessionmaker

DATABASE_URL = "sqlite:///./test.db"  # Uses an SQLite database file for simplicity

engine = create_engine(DATABASE_URL, connect_args={"check_same_thread": False})
SessionLocal = sessionmaker(autocommit=False, autoflush=False, bind=engine)
metadata = MetaData()

# %%
# models.py setup in Jupyter

from sqlalchemy import Column, Integer, String, DateTime, Enum, ForeignKey
from sqlalchemy.orm import declarative_base
import datetime

Base = declarative_base()

class Contact(Base):
    __tablename__ = "contacts"
    
    id = Column(Integer, primary_key=True, index=True)
    phoneNumber = Column(String, nullable=True)
    email = Column(String, nullable=True)
    linkedId = Column(Integer, ForeignKey('contacts.id'), nullable=True)  # Points to another contact if linked
    linkPrecedence = Column(Enum("primary", "secondary", name="link_precedence"), default="primary")
    createdAt = Column(DateTime, default=datetime.datetime.utcnow)
    updatedAt = Column(DateTime, default=datetime.datetime.utcnow, onupdate=datetime.datetime.utcnow)
    deletedAt = Column(DateTime, nullable=True)

# Create the tables
Base.metadata.create_all(bind=engine)

# %%
# services.py logic in Jupyter

from sqlalchemy.orm import Session
from sqlalchemy import or_

def find_or_create_contact(db: Session, email: str, phone_number: str):
    # Fetch contacts with matching email or phone number
    contacts = db.query(Contact).filter(
        or_(Contact.email == email, Contact.phoneNumber == phone_number)
    ).all()

    if contacts:
        primary_contact = next((contact for contact in contacts if contact.linkPrecedence == "primary"), contacts[0])
        emails = {c.email for c in contacts if c.email}
        phone_numbers = {c.phoneNumber for c in contacts if c.phoneNumber}
        secondary_ids = [c.id for c in contacts if c.linkPrecedence == "secondary"]

        if email not in emails or phone_number not in phone_numbers:
            new_contact = Contact(
                email=email,
                phoneNumber=phone_number,
                linkedId=primary_contact.id,
                linkPrecedence="secondary"
            )
            db.add(new_contact)
            db.commit()
            db.refresh(new_contact)
            secondary_ids.append(new_contact.id)
            emails.add(email)
            phone_numbers.add(phone_number)
        
        return {
            "primaryContactId": primary_contact.id,
            "emails": list(emails),
            "phoneNumbers": list(phone_numbers),
            "secondaryContactIds": secondary_ids
        }
    else:
        new_contact = Contact(email=email, phoneNumber=phone_number, linkPrecedence="primary")
        db.add(new_contact)
        db.commit()
        db.refresh(new_contact)
        
        return {
            "primaryContactId": new_contact.id,
            "emails": [new_contact.email],
            "phoneNumbers": [new_contact.phoneNumber],
            "secondaryContactIds": []
        }

# %%
# app.py setup in Jupyter

from fastapi import FastAPI, Depends, HTTPException
import nest_asyncio
from sqlalchemy.orm import Session

# Apply nest_asyncio to allow FastAPI to run in Jupyter
nest_asyncio.apply()

# Initialize FastAPI app
app = FastAPI()

# Dependency to get DB session
def get_db():
    db = SessionLocal()
    try:
        yield db
    finally:
        db.close()

@app.post("/identify")
async def identify_contact(email: str, phone_number: str, db: Session = Depends(get_db)):
    try:
        result = find_or_create_contact(db, email, phone_number)
        return result
    except Exception as e:
        raise HTTPException(status_code=500, detail="An unexpected error occurred")

# %%
import uvicorn

# Start the Uvicorn server
uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# INFO:     Started server process [17204]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     127.0.0.1:57696 - "GET / HTTP/1.1" 404 Not Found
# INFO:     127.0.0.1:51442 - "GET / HTTP/1.1" 404 Not Found
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# INFO:     Finished server process [17204]

# %%
curl -X POST "http://127.0.0.1:8000/identify" -H "Content-Type: application/json" -d '{"email": "test@example.com", "phone_number": "1234567890"}'
# Out:
#   Cell In[9], line 1
#     curl -X POST "http://127.0.0.1:8000/identify" -H "Content-Type: application/json" -d '{"email": "test@example.com", "phone_number": "1234567890"}'
#             ^
# SyntaxError: invalid syntax
